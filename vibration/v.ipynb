# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('./vibration.xlsx')

# %%
df = df.T

# %%
df
# Out:
#            0         1         2         3         4         5         6     \
# 1     -0.018250 -0.043159 -0.066874 -0.055648 -0.010082  0.032946  0.029622
# 1.1   -0.016052 -0.009666 -0.021957 -0.037181 -0.043942 -0.057375 -0.063083
# 1.2    0.026337  0.020389 -0.009363 -0.041877 -0.048847 -0.036165 -0.012410
# 1.3   -0.047333 -0.020183 -0.022399 -0.037398 -0.031188 -0.019561 -0.032608
# 1.4   -0.022949 -0.029152 -0.021174 -0.001796  0.015025  0.017562 -0.007554
# ...         ...       ...       ...       ...       ...       ...       ...
# 1.931 -0.040588 -0.046244 -0.018402  0.040702  0.122282  0.124606  0.085457
# 1.932 -0.132568 -0.165500 -0.081477  0.070376  0.156792  0.086863  0.038356
# 1.933 -0.031311 -0.077527 -0.085391 -0.065479 -0.010504  0.039101  0.029941
# 1.934 -0.054504 -0.055313  0.019586  0.082279  0.095267  0.127675  0.031639
# 1.935 -0.102173 -0.006859  0.075102  0.115169  0.121937  0.071012 -0.010256
#
# ...

# %%
df.shape
# Out:
# (936, 3600)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#          0         1         2         3         4         5         6     \
# 0   -0.018250 -0.043159 -0.066874 -0.055648 -0.010082  0.032946  0.029622
# 1   -0.016052 -0.009666 -0.021957 -0.037181 -0.043942 -0.057375 -0.063083
# 2    0.026337  0.020389 -0.009363 -0.041877 -0.048847 -0.036165 -0.012410
# 3   -0.047333 -0.020183 -0.022399 -0.037398 -0.031188 -0.019561 -0.032608
# 4   -0.022949 -0.029152 -0.021174 -0.001796  0.015025  0.017562 -0.007554
# ..        ...       ...       ...       ...       ...       ...       ...
# 931 -0.040588 -0.046244 -0.018402  0.040702  0.122282  0.124606  0.085457
# 932 -0.132568 -0.165500 -0.081477  0.070376  0.156792  0.086863  0.038356
# 933 -0.031311 -0.077527 -0.085391 -0.065479 -0.010504  0.039101  0.029941
# 934 -0.054504 -0.055313  0.019586  0.082279  0.095267  0.127675  0.031639
# 935 -0.102173 -0.006859  0.075102  0.115169  0.121937  0.071012 -0.010256
#
#          7         8         9     ...      3590      3591      3592  \
# ...

# %%
df['model']=None

# %%
df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.018250 -0.043159 -0.066874 -0.055648 -0.010082  0.032946  0.029622
# 1   -0.016052 -0.009666 -0.021957 -0.037181 -0.043942 -0.057375 -0.063083
# 2    0.026337  0.020389 -0.009363 -0.041877 -0.048847 -0.036165 -0.012410
# 3   -0.047333 -0.020183 -0.022399 -0.037398 -0.031188 -0.019561 -0.032608
# 4   -0.022949 -0.029152 -0.021174 -0.001796  0.015025  0.017562 -0.007554
# ..        ...       ...       ...       ...       ...       ...       ...
# 931 -0.040588 -0.046244 -0.018402  0.040702  0.122282  0.124606  0.085457
# 932 -0.132568 -0.165500 -0.081477  0.070376  0.156792  0.086863  0.038356
# 933 -0.031311 -0.077527 -0.085391 -0.065479 -0.010504  0.039101  0.029941
# 934 -0.054504 -0.055313  0.019586  0.082279  0.095267  0.127675  0.031639
# 935 -0.102173 -0.006859  0.075102  0.115169  0.121937  0.071012 -0.010256
#
#             7         8         9  ...      3591      3592      3593  \
# ...

# %%
df.iloc[0:104,3600]=0
df.iloc[104:208,3600]=1
df.iloc[208:312,3600]=2
df.iloc[312:416,3600]=3
df.iloc[416:520,3600]=4
df.iloc[520:624,3600]=5
df.iloc[624:728,3600]=6
df.iloc[728:832,3600]=7
df.iloc[832:936,3600]=8

# %%
df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.018250 -0.043159 -0.066874 -0.055648 -0.010082  0.032946  0.029622
# 1   -0.016052 -0.009666 -0.021957 -0.037181 -0.043942 -0.057375 -0.063083
# 2    0.026337  0.020389 -0.009363 -0.041877 -0.048847 -0.036165 -0.012410
# 3   -0.047333 -0.020183 -0.022399 -0.037398 -0.031188 -0.019561 -0.032608
# 4   -0.022949 -0.029152 -0.021174 -0.001796  0.015025  0.017562 -0.007554
# ..        ...       ...       ...       ...       ...       ...       ...
# 931 -0.040588 -0.046244 -0.018402  0.040702  0.122282  0.124606  0.085457
# 932 -0.132568 -0.165500 -0.081477  0.070376  0.156792  0.086863  0.038356
# 933 -0.031311 -0.077527 -0.085391 -0.065479 -0.010504  0.039101  0.029941
# 934 -0.054504 -0.055313  0.019586  0.082279  0.095267  0.127675  0.031639
# 935 -0.102173 -0.006859  0.075102  0.115169  0.121937  0.071012 -0.010256
#
#             7         8         9  ...      3591      3592      3593  \
# ...

# %%
X
# Out:
#          0         1         2         3         4         5         6     \
# 0   -0.018250 -0.043159 -0.066874 -0.055648 -0.010082  0.032946  0.029622
# 1   -0.016052 -0.009666 -0.021957 -0.037181 -0.043942 -0.057375 -0.063083
# 2    0.026337  0.020389 -0.009363 -0.041877 -0.048847 -0.036165 -0.012410
# 3   -0.047333 -0.020183 -0.022399 -0.037398 -0.031188 -0.019561 -0.032608
# 4   -0.022949 -0.029152 -0.021174 -0.001796  0.015025  0.017562 -0.007554
# ..        ...       ...       ...       ...       ...       ...       ...
# 931 -0.040588 -0.046244 -0.018402  0.040702  0.122282  0.124606  0.085457
# 932 -0.132568 -0.165500 -0.081477  0.070376  0.156792  0.086863  0.038356
# 933 -0.031311 -0.077527 -0.085391 -0.065479 -0.010504  0.039101  0.029941
# 934 -0.054504 -0.055313  0.019586  0.082279  0.095267  0.127675  0.031639
# 935 -0.102173 -0.006859  0.075102  0.115169  0.121937  0.071012 -0.010256
#
#          7         8         9     ...      3590      3591      3592  \
# ...

# %%
y=df['model']

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
Y = pd.DataFrame(y)
Y.to_excel('y.xlsx')

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 931    8
# 932    8
# 933    8
# 934    8
# 935    8
# Name: model, Length: 936, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9y/tb38wdxj31gbntkhlnyfch980000gn/T/ipykernel_6727/204942281.py in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 clf=RandomForestClassifier(n_estimators=100)
# ----> 3 clf.fit(X_train,y_train)
#       4
#       5 y_pred=clf.predict(X_test)
#
# ~/opt/anaconda3/envs/scikit-learn/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     365         self.n_outputs_ = y.shape[1]
#     366
# --> 367         y, expanded_class_weight = self._validate_y_class_weight(y)
#     368
#     369         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~/opt/anaconda3/envs/scikit-learn/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     722
#     723     def _validate_y_class_weight(self, y):
# ...

# %%
y_pred

# %%
y_test

# %%
from sklearn import metrics

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
